# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

# %%
tweets_list1 = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('#KEY since:2022-06-07 until:2022-7-6').get_items()): #declare a username 
    if i>10000:
        break
    tweets_list1.append([tweet.date, tweet.id, tweet.content, tweet.user.username])
    
tweets_df1 = pd.DataFrame(tweets_list1, columns=['Datetime', 'Tweet Id', 'Text', 'Username'])

# %%
# from datetime import date
# today = str(date.today())
# today.split("-")[1] = str(int(today.split("-")[1])-1)
# print(today)

# %%
tweets_df1
# Out:
#                        Datetime             Tweet Id  \
# 0     2022-07-05 23:54:04+00:00  1544469692978536448
# 1     2022-07-05 23:48:53+00:00  1544468388289753088
# 2     2022-07-05 23:44:54+00:00  1544467386572603392
# 3     2022-07-05 23:40:25+00:00  1544466259093618688
# 4     2022-07-05 23:40:07+00:00  1544466184673918979
# ...                         ...                  ...
# 9996  2022-06-07 02:11:28+00:00  1533995024773685249
# 9997  2022-06-07 02:07:25+00:00  1533994002860883968
# 9998  2022-06-07 02:05:58+00:00  1533993637700304896
# 9999  2022-06-07 02:05:46+00:00  1533993589130526720
# 10000 2022-06-07 02:03:17+00:00  1533992962719264768
#
#                                                     Text      Username
# 0      When a new #Key has formed. #Amazing #nature #...  ShellyMateer
# 1      おはよう💚\n今日は晴れて蒸し蒸しや〜☀️\n水曜日！ぼちぼち頑張ろうね\n\nキーくん💖\...  emikeyshinee
# 2      La votación para #KEY en Fanplus comienza en 2...  5HINeevoting
# 3      Discover, monitor, analyze, orchestrate and fu...   csmahendran
# 4      The Letter K by Art Paul Schlosser Acrylic on ...  artpaulrocks
# ...                                                  ...           ...
# 9996   #SHINee  #샤이니 @SHINee\n#KEY  #키 https://t.co/e...     IAmGab_17
# 9997   #SHINee  #샤이니 @SHINee\n#KEY  #키 https://t.co/D...     IAmGab_17
# 9998                               #KEY new with #BUSD 👀      Bl444ck4
# 9999   #SHINee  #샤이니 @SHINee\n#KEY  #키 https://t.co/c...     IAmGab_17
# 10000  #Key GOP senators signal age hike to buy semia...  Biel58870077
#
# [10001 rows x 4 columns]
