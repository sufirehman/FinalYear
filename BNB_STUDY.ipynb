# %%
import pandas as pd
from binance import Client
import snscrape.modules.twitter as sntwitter
import seaborn as sns
# from deep_translator import GoogleTranslator
import datetime as dt
# from gensim import corpora
# from nltk.corpus import stopwords
import string
# from nltk.stem.wordnet import WordNetLemmatizer
from datetime import date




# import numpy as np, pandas as pd
# import seaborn as sns
# import matplotlib.pyplot as plt
# from sklearn.datasets import fetch_20newsgroups
# from sklearn.feature_extraction.text import TfidfVectorizer
# from sklearn.naive_bayes import MultinomialNB
# from sklearn.pipeline import make_pipeline
# from sklearn.metrics import confusion_matrix, accuracy_score
# from sklearn.model_selection import train_test_split
sns.set() # use seaborn plotting style

# %%
PUBLIC_KEY = 'WhihdXQmvY9QAObIELyVGAI3h1nvJZDYg1B68H7n0MHn0bISKXMwHozMcxMbaJ0Z'
PRIVATE_KEY = '2auNidRhbGrAG06UWK0MPcPYJtBj9fMFKpAWJsyjTACJLHHIdOHVbsLj8MZopJJ4'
client = Client(PUBLIC_KEY, PRIVATE_KEY)
tickers = client.get_all_tickers()
# print(tickers)
# df = pd.DataFrame()
# for coins in client.get_all_tickers():
#     if((coins["symbol"][-4:]=="BUSD")):
#         historical_data = client.get_historical_klines(
#             coins["symbol"], Client.KLINE_INTERVAL_4HOUR, "1 September 2022",'2 October 2022')
        # coin_df = pd.DataFrame(historical_data,columns = ['Open Time', 'Open', 'High', 'Low', 'Close', 'Volume', 'Close Time',
        #         'Quote Asset Volume', 'Number of Trades', 'TB Base Volume', 'TB Quote Volume', 'Ignore'])
#         coin_df["COIN"]=coins["symbol"][:-4]
#         df = pd.concat([df,coin_df],axis=0)
# df['Open Time'] = pd.to_datetime(df['Open Time']/1000, unit='s')
# df['Close Time'] = pd.to_datetime(df['Close Time']/1000, unit='s')
# numeric_columns = ['Open', 'High', 'Low', 'Close', 'Volume',
#                    'Quote Asset Volume', 'TB Base Volume', 'TB Quote Volume']
# df[numeric_columns] = df[numeric_columns].apply(pd.to_numeric, axis=1)
# df["Change"] = ((df["High"]-df["Low"])/df["Low"]).apply(lambda x: x*100)

# %%
# df[df['COIN']=='BNB']

# %%
client.get_all_tickers()
historical_data = client.get_historical_klines("SUNBUSD", Client.KLINE_INTERVAL_1HOUR,"1 month ago UTC")
coin_df = pd.DataFrame(historical_data,columns = ['Open Time', 'Open', 'High', 'Low', 'Close', 'Volume', 'Close Time',\
                'Quote Asset Volume', 'Number of Trades', 'TB Base Volume', 'TB Quote Volume', 'Ignore'])
coin_df['Open Time'] = pd.to_datetime(coin_df['Open Time']/1000, unit='s')
coin_df['Close Time'] = pd.to_datetime(coin_df['Close Time']/1000, unit='s')
numeric_columns = ['Open', 'High', 'Low', 'Close', 'Volume',
                   'Quote Asset Volume', 'TB Base Volume', 'TB Quote Volume']
coin_df[numeric_columns] = coin_df[numeric_columns].apply(pd.to_numeric, axis=1)
coin_df["Change"] = ((coin_df["High"]-coin_df["Low"])/coin_df["Low"]).apply(lambda x: x*100)
coin_df
# Out:
#               Open Time     Open     High      Low    Close       Volume  \
# 0   2022-09-02 23:00:00  0.00576  0.00577  0.00575  0.00576     224413.0
# 1   2022-09-03 00:00:00  0.00577  0.00578  0.00575  0.00577     203232.0
# 2   2022-09-03 01:00:00  0.00577  0.00579  0.00577  0.00578      91504.0
# 3   2022-09-03 02:00:00  0.00578  0.00579  0.00577  0.00577      98249.0
# 4   2022-09-03 03:00:00  0.00577  0.00577  0.00577  0.00577          0.0
# ..                  ...      ...      ...      ...      ...          ...
# 715 2022-10-02 18:00:00  0.00757  0.00759  0.00732  0.00740  102064478.0
# 716 2022-10-02 19:00:00  0.00740  0.00751  0.00733  0.00749   55753558.0
# 717 2022-10-02 20:00:00  0.00749  0.00750  0.00718  0.00723   68020879.0
# 718 2022-10-02 21:00:00  0.00723  0.00750  0.00710  0.00724   72907175.0
# 719 2022-10-02 22:00:00  0.00724  0.00725  0.00715  0.00725   13834672.0
#
#                        Close Time  Quote Asset Volume  Number of Trades  \
# 0   2022-09-02 23:59:59.999000064          1292.94321                15
# 1   2022-09-03 00:59:59.999000064          1171.66302                16
# 2   2022-09-03 01:59:59.999000064           528.91336                12
# 3   2022-09-03 02:59:59.999000064           567.66930                 8
# 4   2022-09-03 03:59:59.999000064             0.00000                 0
# ..                            ...                 ...               ...
# 715 2022-10-02 18:59:59.999000064        759575.07208              3950
# 716 2022-10-02 19:59:59.999000064        414326.82851              2224
# 717 2022-10-02 20:59:59.999000064        497431.87904              2321
# 718 2022-10-02 21:59:59.999000064        525217.34000              2622
# 719 2022-10-02 22:59:59.999000064         99481.07547               657
#
#      TB Base Volume  TB Quote Volume Ignore    Change
# 0           93734.0        540.50962      0  0.347826
# 1           52012.0        300.45451      0  0.521739
# 2           62767.0        362.87949      0  0.346620
# 3           33409.0        193.32410      0  0.346620
# 4               0.0          0.00000      0  0.000000
# ..              ...              ...    ...       ...
# 715      44589231.0     332442.23634      0  3.688525
# 716      26597828.0     197703.22213      0  2.455662
# 717      29659060.0     217110.34119      0  4.456825
# 718      35650851.0     257491.72617      0  5.633803
# 719       7724474.0      55576.58447      0  1.398601
#
# [720 rows x 13 columns]

# %%
import plotly.graph_objects as go

import pandas as pd
from datetime import datetime


fig = go.Figure(data=[go.Candlestick(x=coin_df['Open Time'],
                open=coin_df['Open'],
                high=coin_df['High'],
                low=coin_df['Low'],
                close=coin_df['Close'])])

fig.show()

# %%
coin_df['Open Time'].dtype
# Out:
# dtype('<M8[ns]')

# %%
def Evaluation_Criteria(df,T1,T2,T3,SL,Time):
    if(df["Open Time"].any()>Time):
        if df["High"].any()>T1:
            print(df)

# %%
T1 = 0.08
T2 = 0.085
T3 = 0.09
SL = 0.075
Time =  "2022-09-02 23:00:00"
Evaluation_Criteria(coin_df,T1,T2,T3,SL,Time)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\Mohib\Desktop\Final Year\FinalYear\BNB_STUDY.ipynb Cell 7 in <cell line: 6>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Mohib/Desktop/Final%20Year/FinalYear/BNB_STUDY.ipynb#X23sZmlsZQ%3D%3D?line=3'>4</a> SL = 0.075
#       <a href='vscode-notebook-cell:/c%3A/Users/Mohib/Desktop/Final%20Year/FinalYear/BNB_STUDY.ipynb#X23sZmlsZQ%3D%3D?line=4'>5</a> Time =  "2022-09-02 23:00:00"
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Mohib/Desktop/Final%20Year/FinalYear/BNB_STUDY.ipynb#X23sZmlsZQ%3D%3D?line=5'>6</a> Evaluation_Criteria(coin_df,T1,T2,T3,SL,Time)
#
# c:\Users\Mohib\Desktop\Final Year\FinalYear\BNB_STUDY.ipynb Cell 7 in Evaluation_Criteria(df, T1, T2, T3, SL, Time)
#       <a href='vscode-notebook-cell:/c%3A/Users/Mohib/Desktop/Final%20Year/FinalYear/BNB_STUDY.ipynb#X23sZmlsZQ%3D%3D?line=0'>1</a> def Evaluation_Criteria(df,T1,T2,T3,SL,Time):
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Mohib/Desktop/Final%20Year/FinalYear/BNB_STUDY.ipynb#X23sZmlsZQ%3D%3D?line=1'>2</a>     if(df["Open Time"].any()>Time):
#       <a href='vscode-notebook-cell:/c%3A/Users/Mohib/Desktop/Final%20Year/FinalYear/BNB_STUDY.ipynb#X23sZmlsZQ%3D%3D?line=2'>3</a>         if df["High"].any()>T1:
#       <a href='vscode-notebook-cell:/c%3A/Users/Mohib/Desktop/Final%20Year/FinalYear/BNB_STUDY.ipynb#X23sZmlsZQ%3D%3D?line=3'>4</a>             print(df)
#
# TypeError: '>' not supported between instances of 'numpy.ndarray' and 'str'
